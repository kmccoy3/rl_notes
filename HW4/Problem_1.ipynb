# %% [markdown]
# We first install and import necessary packages.

# %%
# !pip install torch
# !pip install swig
# !pip install gymnasium
# !pip install gymnasium[box2d] 
# !pip install stable-baselines3
# !pip install pygame
# !pip install ufal.pybox2d

# %%
import gymnasium as gym

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as functional

import matplotlib.pyplot as plt

# %% [markdown]
# ## Lunar Lander
#
# Next, we instantiate the [Lunar Lander environment](https://www.gymlibrary.dev/environments/box2d/lunar_lander/) from OpenAI Gym and gain a quick understanding of its key variables and methods.
#
# The Lunar Lander environment models a rocket that needs to land on the moon. Follow the hyperlinks to learn more about the envionment [Acrobot environment](https://www.gymlibrary.dev/environments/box2d/lunar_lander/). In this assignment, we will use the Continuous (v2) version of the environment in which both the state and action spaces are continuous.
#
# ![](https://www.gymlibrary.dev/_images/lunar_lander.gif)

# %%
env = gym.make("LunarLanderContinuous-v2")

# %% [markdown]
# #### States
#
# OpenAI Gym environments do not explicitly provide state but instead provide observation. In the Lunar Lander environment, the state and observation are identical. The state of the Lander is a 8-dimensional vector: the coordinates of the lander in x and y, its linear velocities in x and y, its angle, its angular velocity, and two booleans that represent whether each leg is in contact with the ground or not.

# %%
print(f"Number of state features: {env.observation_space.shape[0]}")
# Out:
# Number of state features: 8

# %% [markdown]
# #### Actions
#
# The action space is also continous and includes two features. The first coordinate of an action determines the throttle of the main engine, while the second coordinate specifies the throttle of the lateral boosters.
#
# Given an action `np.array([main, lateral])`, the main engine will be turned off completely if `main < 0` and the throttle scales affinely from 50% to 100% for `0 <= main <= 1` (i.e., the main engine doesn’t work with less than 50% power). Similarly, if `-0.5 < lateral < 0.5`, the lateral boosters will not fire at all. If `lateral < -0.5`, the left booster will fire, and if `lateral > 0.5`, the right booster will fire. Again, the throttle scales affinely from 50% to 100% between -1 and -0.5 (and 0.5 and 1, respectively)

# %%
print(f"Number of action features: {env.action_space.shape[0]}")
# Out:
# Number of action features: 2

# %% [markdown]
# #### Transition and Reward Function
#
# The transition and rewards functions for the environment are not explicitly represented as matrices or tensors. Instead the gym API provides access to the `step` method, which takes in as input an `action` and provides (among other things) an `observation` and `reward`. Also notice the `reset` method, which resets the MDP environment.
#
# The following snippet describes the use of `step` and `reset` methods.

# %%
# Reset the environment
state = env.reset()
print(f"State: {state}")

# Select a random action to play
action = env.action_space.sample()
print(f"Action: {action}")

# Send this action to the environment to receive the next state and reward
next_state, reward, done, _, _ = env.step(action)
print(f"Next state: {next_state}")
print(f"Reward: {reward}")
# Out:
# State: (array([-0.00269032,  1.4067186 , -0.27251542, -0.1867361 ,  0.00312421,
#         0.06172874,  0.        ,  0.        ], dtype=float32), {})
# Action: [ 0.2064892  -0.81549114]
# Next state: [-0.00535192  1.4025099  -0.27097046 -0.18707293  0.00788195  0.09516457
#   0.          0.        ]
# Reward: -0.15290034761616084

# %% [markdown]
# ## Problem 1.1
#
# Next, we will implement the general recipe of the DDPG algorithm to compute the optimal policy for the Lunar Lander.

# %% [markdown]
# #### Actor-Critic Networks
#
# DDPG requires two networks: Actor and Critic. Let us know define these networks.

# %%
class Actor(nn.Module):
  """Actor Network as a Multi-Layer Perceptron."""

  def __init__(self, env, mlp_sizes=[256, 256]):
    """Initialize the Actor Network.

    Args:
        env: An OpenAI Gym environment.
        mlp_sizes: An array of integers. The length of array equals the number
            of hidden layers of the Multi-Layer Perceptron. Each element in the array
            equals the number of nodes in the corresponding layer.
    """
    super().__init__()
    ######## PUT YOUR CODE HERE ########
    # input layer
    self.input_layer = nn.Linear(env.observation_space.shape[0], mlp_sizes[0])

    # hidden layers
    self.hidden_layers = nn.ModuleList()
    for k in range(len(mlp_sizes) - 1):
        self.hidden_layers.append(nn.Linear(mlp_sizes[k], mlp_sizes[k+1]))

    # output layer
    self.output_layer = nn.Linear(mlp_sizes[len(mlp_sizes) - 1], env.action_space.shape[0])

    self.tanh = nn.Tanh()
    self.relu = nn.ReLU()
    ######## PUT YOUR CODE HERE ########

  def forward(self, x):
    """Implements the forward pass of the Actor Network.

    Args:
        x: Input to the Actor Network.

    Returns:
        Output of the Actor Network.
    """
    ######## PUT YOUR CODE HERE ########

    output = self.relu(self.input_layer(x))

    for layer in self.hidden_layers:
        output = layer(output)


    return self.tanh(self.output_layer(output))

    ######## PUT YOUR CODE HERE ########

# %%
class Critic(nn.Module):
  """Critic Network as a Multi-Layer Perceptron."""

  def __init__(self, env, mlp_sizes=[256, 256]):
    """Initialize the Critic Network.

    Args:
        env: An OpenAI Gym environment.
        mlp_sizes: An array of integers. The length of array equals the number
            of hidden layers of the Multi-Layer Perceptron. Each element in the array
            equals the number of nodes in the corresponding layer.
    """
    super().__init__()

    ######## PUT YOUR CODE HERE ########
    # input layer
    self.input_layer = nn.Linear(env.observation_space.shape[0] + env.action_space.shape[0], mlp_sizes[0])

    # hidden layers
    self.hidden_layers = nn.ModuleList()
    for k in range(len(mlp_sizes) - 1):
        self.hidden_layers.append(nn.Linear(mlp_sizes[k], mlp_sizes[k+1]))

    # output layer
    self.output_layer = nn.Linear(mlp_sizes[len(mlp_sizes) - 1], 1)

    self.relu = nn.ReLU()

    ######## PUT YOUR CODE HERE ########

  def forward(self, x):
    """Implements the forward pass of the Critic Network.

    Args:
        x: Input to the Critic Network.

    Returns:
        Output of the Critic Network.
    """
    ######## PUT YOUR CODE HERE ########

    output = self.relu(self.input_layer(x))

    for layer in self.hidden_layers:
        output = self.relu(layer(output))


    return self.output_layer(output)

    ######## PUT YOUR CODE HERE ########

# %% [markdown]
# #### Replay Buffer
#
# DDPG requires a data structure to store the agent's experiences: Replay Buffer. Let us now define this data structure.

# %%
class ReplayBuffer:
  """A buffer to store agent's experiences."""

  def __init__(self, env, buffer_size):
    """Initialize a buffer to store agent's experiences.

    Args:
        env: An OpenAI Gym environment.
        buffer_size: An integer. The size of the buffer.
    """
    observation_n = env.observation_space.shape[0]
    action_n = env.action_space.shape[0]

    self.buffer_size = buffer_size
    self.observations = np.zeros((self.buffer_size, observation_n), dtype=np.float32)
    self.next_observations = np.zeros((self.buffer_size, observation_n), dtype=np.float32)
    self.actions = np.zeros((self.buffer_size, action_n), dtype=np.float32)
    self.rewards = np.zeros((self.buffer_size,), dtype=np.float32)
    self.dones = np.zeros((self.buffer_size,), dtype=np.float32)

    self.size = 0
    self.pos = 0

  def add(self, observation, next_observation, action, reward, done):
    """Add an experience to the buffer.

    Args:
        observation: the current environment state
        next_observation: the state after executing the action
        action: the action executed in the state
        reward: the reward received after executing the action
        done: Boolean denoting whether the task is completed.
    """
    self.observations[self.pos] = observation
    self.next_observations[self.pos] = next_observation
    self.actions[self.pos] = action
    self.rewards[self.pos] = reward
    self.dones[self.pos] = 1.0 if done else 0.0

    self.pos += 1
    if self.size < self.buffer_size:
      self.size += 1
    if self.pos == self.buffer_size:
      self.pos = 0

  def sample(self, batch_size):
    """Sample a mini-batch of experiences from the replay buffer.
    For ease of implementation, we sample with replacement.

    Args:
        batch_size: An integer. The size of the mini-batch.

    Returns:
        Randomly sampled experiences from the replay buffer.
    """
    indices = np.random.randint(self.size, size=batch_size)
    observations = torch.from_numpy(self.observations[indices])
    next_observations = torch.from_numpy(self.next_observations[indices])
    actions = torch.from_numpy(self.actions[indices])
    rewards = torch.from_numpy(self.rewards[indices])
    dones = torch.from_numpy(self.dones[indices])

    return observations, next_observations, actions, rewards, dones

# %% [markdown]
# #### Exploration schedule
#
# In general, it is useful to explore more initially (when the agent is far from the optimal policy) and less later on in the learning process. To implement this, we can implement a schedule for epsilon.
#
# Similar to the Actor and Critic networks and replay buffer architectures, several choices exist for determining the epsilon schedule. We will use a simple linear scheduler to decay epsilon as agent gains more experience.

# %%
def linear_schedule_for_epsilon(initial_value, final_value, duration, timestep):
  """Implements a linear scheduler for epsilon.

  Args:
      initial_value: (float) Initial value of epsilon.
      final_value: (float) Final value of epsilon.
      duration: (int) Duration over which to decay epsilon from its initial to final value.
      timestep: (int) The current time step.

  Returns:
      Value of epsilon at the given timestep.
  """
  slope = (final_value - initial_value) / duration
  return max(slope * timestep + initial_value, final_value)

# %% [markdown]
# #### Target Networks
# In DDPG, we will update the target network in each iteration of the algorithm. A utility function to update the weights of the target network is provided below.

# %%
def update_weights(src, target, tau=1.0):
  """Utility function to update the target network using Polyak averaging.

  Args:
    src: (target network) source network
    target: (neural network) target network
    tau: (float) Polyak factor
  """

  for target_param, param in zip(target.parameters(), src.parameters()):
    target_param.data.copy_(
        target_param.data * (1.0 - tau) + param.data * tau
    )

# %% [markdown]
# #### DDPG algorithm
#
# Now that we have all the building blocks, we will implement the DDPG algorithm.
#
# We will use the AgentBase class from Assignment 2 to help us with the implementation.

# %%
class AgentBase:
  def __init__(self, env):
    self.env = env
    self.policy = self.make_policy()
    self.behavior_policy = self.make_behavior_policy()

  def make_policy(self):
    """
    Return a policy function that will be used for evaluation. The policy
    takes observation as input and return action
    """
    raise NotImplementedError

  def make_behavior_policy(self):
    """
    Similar to make_policy, it returns a policy function. But this one used
    for interaction with the environment.
    """
    raise NotImplementedError

  def run_episode(self, episode_policy):
    """
    Generate one episode with the given policy
    """
    episode = []
    done = False
    obs = self.env.reset()[0]
    episode_return = 0
    while not done:
      action = episode_policy(obs)
      next_obs, reward, done, truncated, _ = self.env.step(action)
      done = done or truncated
      episode.append([obs, action, reward, next_obs, done])
      obs = next_obs
      episode_return += reward

    return (episode, episode_return)

  def evaluate(self, num_eval_episodes=1000, plot_title="Evaluation"):
    """Evaluates the agent."""
    list_returns = []
    list_average_returns = []
    average_return = 0
    for episode_idx in range(num_eval_episodes):
      _, episode_return = self.run_episode(self.policy)
      average_return += (1. / (episode_idx+1)) * (episode_return - average_return)
      list_returns.append(episode_return)
      list_average_returns.append(average_return)

    print(f"Average reward {round(average_return, 3)}")
    plt.plot(list_returns,'^',label="Return")
    plt.plot(list_average_returns,'r',label="Average Return")
    plt.ylabel('Return')
    plt.xlabel('Episode#')
    plt.title(plot_title)
    plt.legend()
    plt.ylim(-501, 0.0)
    plt.show()

# %%
class DDPG(AgentBase):
  """Implements DDPG."""

  def __init__(
    self,
    env,
    actor_lr=0.001,
    critic_lr=0.001,
    total_timesteps=100000,
    buffer_size=100000,
    warmup_steps=10000,
    batch_size=100,
    tau=0.005,
    noise_std=0.05,
  ):
    """Initializes the Agent.
    Args:
        env: An OpenAI Gym environment.
        actor_lr: (float) Learning rate of actor
        critic_lr: (float) Learning rate of critic
        total_timesteps: (integer) The number of timesteps in training
        buffer_size: (integer) Size of the replay buffer.
        warmup_steps: (integer) Size of data for pre-filling buffer
        batch_size: (integer) Size of the mini batch.
        tau: (float) The amount of update to target actor/critic
        noise_std: (float) Initial noise level for exploration.
    """
    super().__init__(env=env)

    self.gamma = 0.99 # Assume a discount factor of 0.99
    self.env = env
    self.actor_lr = actor_lr
    self.critic_lr = critic_lr
    self.total_timesteps = total_timesteps
    self.buffer_size = buffer_size
    self.warmup_steps = warmup_steps
    self.batch_size = batch_size
    self.tau = tau
    self.noise_std = noise_std

    # Create actor and critic
    ######## PUT YOUR CODE HERE ########
    self.actor = Actor(env)
    self.actor_target = Actor(env)
    self.critic = Critic(env)
    self.critic_target = Critic(env)
    ######## PUT YOUR CODE HERE ########

    # Copy weights to target networks
    update_weights(self.actor, self.actor_target)
    update_weights(self.critic, self.critic_target)

    # Create optimizers
    ######## PUT YOUR CODE HERE ########
    self.actor_optim = torch.optim.Adam(self.actor.parameters(), lr=self.actor_lr)
    self.critic_optim = torch.optim.Adam(self.critic.parameters(), lr=self.critic_lr)
    ######## PUT YOUR CODE HERE ########

    # Create replay buffer
    ######## PUT YOUR CODE HERE ########
    self.replay_buffer = ReplayBuffer(env, buffer_size)
    ######## PUT YOUR CODE HERE ########

    # Create variables for logging
    self.obs = env.reset()[0]
    self.current_step = 0
    self.list_returns = []
    self.list_average_returns = []
    self.average_return = 0.
    self.list_moving_average_returns = []

    self.num_actions = env.action_space.shape[0]

        # Create exploration scheduler
  #   self.epsilon_scheduler = lambda current_step: linear_schedule_for_epsilon(
  #       1.0, 0.01, total_timesteps, current_step)


  # @property
  # def epsilon(self):
  #     return self.epsilon_scheduler(self.current_step)


  def make_policy(self):
    def policy_func(observation):
      ######## PUT YOUR CODE HERE ########
      observation = torch.tensor(observation)

      output = self.actor.forward(observation).detach().numpy()

      return output
      ######## PUT YOUR CODE HERE ########

    return policy_func

  def make_behavior_policy(self):
    def policy_func(observation):
      ######## PUT YOUR CODE HERE ########
      observation = torch.tensor(observation)

      output = self.actor.forward(observation).detach().numpy() + np.random.normal(scale=self.noise_std**0.5, size=2)

      output[0] = np.clip(output[0], 0, 1)
      output[1] = np.clip(output[1], -1, 1)

      return output
      ######## PUT YOUR CODE HERE ########

    return policy_func

  def update(self):
    if self.current_step > self.warmup_steps:
      ######## PUT YOUR CODE HERE ########
      # Sample a batch
      observations, next_observations, actions, rewards, dones = self.replay_buffer.sample(self.batch_size)
      rewards = rewards.unsqueeze(1)
      dones = dones.unsqueeze(1)


      # Get target values
      input_ = torch.cat((next_observations, self.actor_target.forward(next_observations)), dim=1)
      target = rewards + self.gamma * self.critic_target.forward(input_) * (1.0 - dones)

      # Decay learning rate
      # self.actor_lr = self.actor_lr * 0.999
      # self.critic_lr = self.critic_lr * 0.999

      # Update critic
      self.critic_optim.zero_grad()
      loss_fn = nn.MSELoss()
      input_ = torch.cat((observations, actions), dim=1)
      out = self.critic.forward(input_)
      loss1 = loss_fn(out, target.detach())
      loss1.backward()
      self.critic_optim.step()

      # Update actor
      self.actor_optim.zero_grad()
      input_ = torch.cat((observations, self.actor.forward(observations)), dim=1)
      out = -self.critic.forward(input_)
      loss2 = out.mean()
      loss2.backward()
      self.actor_optim.step()

      ######## PUT YOUR CODE HERE ########

    # Update Target Network
    update_weights(self.actor, self.actor_target, self.tau)
    update_weights(self.critic, self.critic_target, self.tau)


  def train(self, make_plot=False):
    episode_return = 0.
    while self.current_step < self.total_timesteps:

      # Interact with env
      action = self.behavior_policy(self.obs)
      next_obs, reward, done, truncated, info = self.env.step(action)
      episode_return += reward
      done = done or truncated

      if done:
        # Store the return for evaluation
        self.list_returns.append(episode_return)
        episode_return = 0.
        self.average_return = np.mean(np.asarray(self.list_returns))
        self.list_average_returns.append(self.average_return)

        if len(self.list_average_returns) > 20:
          self.list_moving_average_returns.append(np.mean(self.list_returns[-20:]))
        else:
          self.list_moving_average_returns.append(self.average_return)

      # Save data into buffer
      self.replay_buffer.add(self.obs, next_obs, action, reward, done)

      # Update networks
      self.update()

      # Prepare for next iteration
      if done:
        self.obs = env.reset()[0]
      else:
        self.obs = next_obs

      if self.current_step % 1000 == 999:
        print(f"Timestep: {self.current_step+1}, episode reward (moving average, 20 episodes): {round(self.list_moving_average_returns[-1],2)}")
      self.current_step += 1

    if make_plot:
      plt.plot(self.list_returns,'^',label="Return")
      plt.plot(self.list_average_returns,'r',label="Average Return (all episodes)")
      plt.plot(self.list_moving_average_returns,'b',label="Average Return (last 20 episodes)")
      plt.ylabel('Return')
      plt.xlabel('Episode#')
      plt.title('Performance during training')
      plt.ylim(-501, 300)
      plt.legend()
      plt.show()

# %% [markdown]
# #### Training the Agent
#
# Having implemented the agent, now we will train it using the default hyperparameters provided in the class definition and observe its performance.

# %%
env = gym.make("LunarLanderContinuous-v2")

# %%
agent_001 = DDPG(env)
agent_001.train(make_plot=True)
# Out:
# Timestep: 1000, episode reward (moving average, 20 episodes): -201.2
# The performance of RL algorithms typically varies across runs. Report results of five runs of your algorithm and summarize the performance in a single plot.

# %%
######## PUT YOUR CODE HERE ########
agent_002 = DDPG(env, total_timesteps=100000)
agent_002.train()

agent_003 = DDPG(env, total_timesteps=100000)
agent_003.train()

agent_004 = DDPG(env, total_timesteps=100000)
agent_004.train()

agent_005 = DDPG(env, total_timesteps=100000)
agent_005.train()

######## PUT YOUR CODE HERE ########
# Out:
# Timestep: 1000, episode reward (moving average, 20 episodes): -226.49
# Timestep: 2000, episode reward (moving average, 20 episodes): -258.19
# Timestep: 3000, episode reward (moving average, 20 episodes): -251.42
# Timestep: 4000, episode reward (moving average, 20 episodes): -288.13
# Timestep: 5000, episode reward (moving average, 20 episodes): -254.84
# Timestep: 6000, episode reward (moving average, 20 episodes): -241.05
# Timestep: 7000, episode reward (moving average, 20 episodes): -191.03
# Timestep: 8000, episode reward (moving average, 20 episodes): -221.97
# Timestep: 9000, episode reward (moving average, 20 episodes): -248.15
# Timestep: 10000, episode reward (moving average, 20 episodes): -246.19
# Timestep: 11000, episode reward (moving average, 20 episodes): -227.35
# Timestep: 12000, episode reward (moving average, 20 episodes): -193.65
# Timestep: 13000, episode reward (moving average, 20 episodes): -203.6
# Timestep: 14000, episode reward (moving average, 20 episodes): -224.94
# Timestep: 15000, episode reward (moving average, 20 episodes): -237.55
# Timestep: 16000, episode reward (moving average, 20 episodes): -228.42
# Timestep: 17000, episode reward (moving average, 20 episodes): -212.49
# Timestep: 18000, episode reward (moving average, 20 episodes): -196.6
# Timestep: 19000, episode reward (moving average, 20 episodes): -159.83
# Timestep: 20000, episode reward (moving average, 20 episodes): -119.7
# Timestep: 21000, episode reward (moving average, 20 episodes): -141.08
# Timestep: 22000, episode reward (moving average, 20 episodes): -203.81
# Timestep: 23000, episode reward (moving average, 20 episodes): -279.72
# Timestep: 24000, episode reward (moving average, 20 episodes): -335.86
# Timestep: 25000, episode reward (moving average, 20 episodes): -344.25
# Timestep: 26000, episode reward (moving average, 20 episodes): -333.82
# Timestep: 27000, episode reward (moving average, 20 episodes): -320.37
# Timestep: 28000, episode reward (moving average, 20 episodes): -264.25
# Timestep: 29000, episode reward (moving average, 20 episodes): -175.61
# Timestep: 30000, episode reward (moving average, 20 episodes): -86.02
# Timestep: 31000, episode reward (moving average, 20 episodes): -73.95
# Timestep: 32000, episode reward (moving average, 20 episodes): -100.55
# Timestep: 33000, episode reward (moving average, 20 episodes): -120.99
# Timestep: 34000, episode reward (moving average, 20 episodes): -120.74
# Timestep: 35000, episode reward (moving average, 20 episodes): -103.52
# Timestep: 36000, episode reward (moving average, 20 episodes): -84.67
# Timestep: 37000, episode reward (moving average, 20 episodes): -70.5
# Timestep: 38000, episode reward (moving average, 20 episodes): -44.71
# Timestep: 39000, episode reward (moving average, 20 episodes): -62.04
# Timestep: 40000, episode reward (moving average, 20 episodes): -58.81
# Timestep: 41000, episode reward (moving average, 20 episodes): -77.32
# Timestep: 42000, episode reward (moving average, 20 episodes): -105.09
# Timestep: 43000, episode reward (moving average, 20 episodes): -126.02
# Timestep: 94000, episode reward (moving average, 20 episodes): -358.57
# Timestep: 95000, episode reward (moving average, 20 episodes): -412.64
# Timestep: 96000, episode reward (moving average, 20 episodes): -525.2
# Timestep: 97000, episode reward (moving average, 20 episodes): -527.66
# Timestep: 98000, episode reward (moving average, 20 episodes): -455.76
# Timestep: 99000, episode reward (moving average, 20 episodes): -458.12
# Timestep: 100000, episode reward (moving average, 20 episodes): -630.11

# %%
plt.plot(agent_001.list_moving_average_returns[:100000],'r')
plt.plot(agent_002.list_moving_average_returns,'g')
plt.plot(agent_003.list_moving_average_returns,'b')
plt.plot(agent_004.list_moving_average_returns,'k')
plt.plot(agent_005.list_moving_average_returns,'c')

plt.ylabel('Return')
plt.xlabel('Episode#')
plt.title('Agent Comparison')
plt.ylim([-500, 500])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Problem 1.3
#
# Select any one hyperparameter of the algorithm and study its effect on the agent's performance.
# You should try at least five different values of this hyperparameter and report on the observed performance. In a single plot, show the performance of the agent for different values of hyperparameter.

# %%
######## PUT YOUR CODE HERE ########

agent_006 = DDPG(env, total_timesteps=100000, actor_lr=0.1, critic_lr=0.1)
agent_006.train()

agent_007 = DDPG(env, total_timesteps=100000, actor_lr=0.01, critic_lr=0.01)
agent_007.train()

agent_008 = DDPG(env, total_timesteps=100000, actor_lr=0.0001, critic_lr=0.0001)
agent_008.train()

agent_009 = DDPG(env, total_timesteps=100000, actor_lr=0.00001, critic_lr=0.00001)
agent_009.train()

######## PUT YOUR CODE HERE ########
# Out:
# Timestep: 1000, episode reward (moving average, 20 episodes): -181.37
# Timestep: 2000, episode reward (moving average, 20 episodes): -205.56
# Timestep: 3000, episode reward (moving average, 20 episodes): -191.91
# Timestep: 4000, episode reward (moving average, 20 episodes): -181.31
# Timestep: 5000, episode reward (moving average, 20 episodes): -210.42
# Timestep: 6000, episode reward (moving average, 20 episodes): -196.46
# Timestep: 7000, episode reward (moving average, 20 episodes): -179.21
# Timestep: 8000, episode reward (moving average, 20 episodes): -159.81
# Timestep: 9000, episode reward (moving average, 20 episodes): -154.49
# Timestep: 10000, episode reward (moving average, 20 episodes): -163.79
# Timestep: 11000, episode reward (moving average, 20 episodes): -665.16
# Timestep: 12000, episode reward (moving average, 20 episodes): -1070.98
# Timestep: 13000, episode reward (moving average, 20 episodes): -1117.35
# Timestep: 14000, episode reward (moving average, 20 episodes): -1082.28
# Timestep: 15000, episode reward (moving average, 20 episodes): -1053.96
# Timestep: 16000, episode reward (moving average, 20 episodes): -1102.22
# Timestep: 17000, episode reward (moving average, 20 episodes): -991.8
# Timestep: 18000, episode reward (moving average, 20 episodes): -963.93
# Timestep: 19000, episode reward (moving average, 20 episodes): -1059.09
# Timestep: 20000, episode reward (moving average, 20 episodes): -994.67
# Timestep: 21000, episode reward (moving average, 20 episodes): -1002.43
# Timestep: 22000, episode reward (moving average, 20 episodes): -1034.44
# Timestep: 23000, episode reward (moving average, 20 episodes): -1034.82
# Timestep: 24000, episode reward (moving average, 20 episodes): -954.1
# Timestep: 25000, episode reward (moving average, 20 episodes): -1100.18
# Timestep: 74000, episode reward (moving average, 20 episodes): -119.12
# Timestep: 75000, episode reward (moving average, 20 episodes): -124.8
# Timestep: 76000, episode reward (moving average, 20 episodes): -135.87
# Timestep: 77000, episode reward (moving average, 20 episodes): -148.92
# Timestep: 78000, episode reward (moving average, 20 episodes): -166.09
# Timestep: 79000, episode reward (moving average, 20 episodes): -160.13
# Timestep: 80000, episode reward (moving average, 20 episodes): -161.06
# Timestep: 81000, episode reward (moving average, 20 episodes): -177.97
# Timestep: 82000, episode reward (moving average, 20 episodes): -164.59
# Timestep: 83000, episode reward (moving average, 20 episodes): -183.52
# Timestep: 84000, episode reward (moving average, 20 episodes): -184.25
# Timestep: 85000, episode reward (moving average, 20 episodes): -160.39
# Timestep: 86000, episode reward (moving average, 20 episodes): -157.35
# Timestep: 87000, episode reward (moving average, 20 episodes): -142.31
# Timestep: 88000, episode reward (moving average, 20 episodes): -157.43
# Timestep: 89000, episode reward (moving average, 20 episodes): -186.05
# Timestep: 90000, episode reward (moving average, 20 episodes): -209.68
# Timestep: 91000, episode reward (moving average, 20 episodes): -223.08
# Timestep: 92000, episode reward (moving average, 20 episodes): -219.71
# Timestep: 93000, episode reward (moving average, 20 episodes): -197.29
# Timestep: 94000, episode reward (moving average, 20 episodes): -200.26
# Timestep: 95000, episode reward (moving average, 20 episodes): -180.86
# Timestep: 96000, episode reward (moving average, 20 episodes): -177.44
# Timestep: 97000, episode reward (moving average, 20 episodes): -172.65
# Timestep: 98000, episode reward (moving average, 20 episodes): -149.03
# Timestep: 99000, episode reward (moving average, 20 episodes): -144.78
# Timestep: 100000, episode reward (moving average, 20 episodes): -124.31

# %%
plt.plot(agent_006.list_moving_average_returns,'g', label="0.1")
plt.plot(agent_007.list_moving_average_returns,'b', label="0.01")
plt.plot(agent_001.list_moving_average_returns,'r', label="0.001")
plt.plot(agent_008.list_moving_average_returns,'k', label="0.0001")
plt.plot(agent_009.list_moving_average_returns,'c', label="0.00001")

plt.ylabel('Return')
plt.xlabel('Episode#')
plt.title('Agent Comparison')
plt.legend()
plt.show()

# %% [markdown]
# ## Problem 1.4
#
# While applying RL in real world, you may consider the use of off-the-shelf implementation of RL algorithms. The package [Stable Baselines 3](stable-baselines3.readthedocs.io/) aims to provide a set of reliable implementations of RL algorithms in PyTorch.
#
# Familiarize yourself with this package and use its implementation of DDPG to learn the optimal policy for the Lunar Lander environment.

# %% [markdown]
# In a single plot, compare the performance of your implementation of the algorithm in Problem 1.1. with the one that you implemented above (Problem 1.4).

# %%
from stable_baselines3 import DQN
from stable_baselines3 import common

import os

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines3 import TD3
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.results_plotter import load_results, ts2xy
from stable_baselines3.common.noise import NormalActionNoise
from stable_baselines3.common.callbacks import BaseCallback

# %%
class SaveOnBestTrainingRewardCallback(BaseCallback):
    """
    Callback for saving a model (the check is done every ``check_freq`` steps)
    based on the training reward (in practice, we recommend using ``EvalCallback``).

    :param check_freq: (int)
    :param log_dir: (str) Path to the folder where the model will be saved.
      It must contains the file created by the ``Monitor`` wrapper.
    :param verbose: (int)
    """

    def __init__(self, check_freq: int, log_dir: str, verbose=1):
        super().__init__(verbose)
        self.check_freq = check_freq
        self.log_dir = log_dir
        self.save_path = os.path.join(log_dir, "best_model")
        self.best_mean_reward = -np.inf

    def _init_callback(self) -> None:
        # Create folder if needed
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self) -> bool:
        if self.n_calls % self.check_freq == 0:

            # Retrieve training reward
            x, y = ts2xy(load_results(self.log_dir), "timesteps")
            if len(x) > 0:
                # Mean training reward over the last 100 episodes
                mean_reward = np.mean(y[-100:])
                if self.verbose > 0:
                    print(f"Num timesteps: {self.num_timesteps}")
                    print(
                        f"Best mean reward: {self.best_mean_reward:.2f} - Last mean reward per episode: {mean_reward:.2f}"
                    )

                # New best model, you could save the agent here
                if mean_reward > self.best_mean_reward:
                    self.best_mean_reward = mean_reward
                    # Example for saving best model
                    if self.verbose > 0:
                        print(f"Saving new best model to {self.save_path}.zip")
                    self.model.save(self.save_path)

        return True

# %%
# Create log dir
log_dir = "./log/"
os.makedirs(log_dir, exist_ok=True)

# Create and wrap the environment
env = gym.make("LunarLanderContinuous-v2")
# Logs will be saved in log_dir/monitor.csv
env = Monitor(env, log_dir)

# Create action noise because TD3 and DDPG use a deterministic policy
n_actions = 2
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
# Create the callback: check every 1000 steps
callback = SaveOnBestTrainingRewardCallback(check_freq=20, log_dir=log_dir)
# Create RL model

# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy


# Create environment



# Instantiate the agent
model = DDPG("MlpPolicy", env, verbose=0)
# Train the agent and display a progress bar
model.learn(total_timesteps=int(1e5), callback=callback)


mean_reward, std_reward = evaluate_policy(model, model.get_env(), n_eval_episodes=10)

# Enjoy trained agent
vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, rewards, dones, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Num timesteps: 100
# Best mean reward: -inf - Last mean reward per episode: -84.00
# Saving new best model to ./log/best_model.zip
# Num timesteps: 120
# Best mean reward: -84.00 - Last mean reward per episode: -84.00
# Num timesteps: 140
# Best mean reward: -84.00 - Last mean reward per episode: -84.00
# Num timesteps: 160
# Best mean reward: -84.00 - Last mean reward per episode: -84.00
# Num timesteps: 180
# Best mean reward: -84.00 - Last mean reward per episode: -84.00
# Num timesteps: 200
# Best mean reward: -84.00 - Last mean reward per episode: -99.16
# Num timesteps: 220
# Best mean reward: -84.00 - Last mean reward per episode: -99.16
# Num timesteps: 240
# Best mean reward: -84.00 - Last mean reward per episode: -99.16
# Num timesteps: 260
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 280
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 300
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 320
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 340
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 360
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 380
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 400
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 420
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 440
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 460
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 480
# Best mean reward: -84.00 - Last mean reward per episode: -386.91
# Num timesteps: 500
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 520
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 540
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 560
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 580
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 600
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 620
# Best mean reward: -84.00 - Last mean reward per episode: -1238.86
# Num timesteps: 640
# Best mean reward: -84.00 - Last mean reward per episode: -1347.37
# Num timesteps: 660
# Best mean reward: -84.00 - Last mean reward per episode: -1347.37
# Num timesteps: 680
# Best mean reward: -84.00 - Last mean reward per episode: -1347.37
# Num timesteps: 700
# Best mean reward: -84.00 - Last mean reward per episode: -1347.37
# Num timesteps: 720
# Best mean reward: -84.00 - Last mean reward per episode: -1347.37
# Num timesteps: 740
# Best mean reward: -84.00 - Last mean reward per episode: -1347.37
# Num timesteps: 760
# Best mean reward: -84.00 - Last mean reward per episode: -1291.05
# Num timesteps: 780
# Best mean reward: -84.00 - Last mean reward per episode: -1291.05
# Num timesteps: 800
# Best mean reward: -84.00 - Last mean reward per episode: -1291.05
# Num timesteps: 820
# Best mean reward: -84.00 - Last mean reward per episode: -1291.05
# Num timesteps: 840
# Best mean reward: -84.00 - Last mean reward per episode: -1291.05
# Num timesteps: 860
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 880
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 900
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 920
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 940
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 960
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 980
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 1000
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 1020
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 1040
# Best mean reward: -84.00 - Last mean reward per episode: -1224.35
# Num timesteps: 1060
# Best mean reward: -84.00 - Last mean reward per episode: -1429.90
# Num timesteps: 1080
# Best mean reward: -84.00 - Last mean reward per episode: -1429.90
# Num timesteps: 1100
# Best mean reward: -84.00 - Last mean reward per episode: -1429.90
# Num timesteps: 1120
# Best mean reward: -84.00 - Last mean reward per episode: -1429.90
# Num timesteps: 1140
# Best mean reward: -84.00 - Last mean reward per episode: -1346.32
# Num timesteps: 1160
# Best mean reward: -84.00 - Last mean reward per episode: -1346.32
# Num timesteps: 1180
# Best mean reward: -84.00 - Last mean reward per episode: -1346.32
# Num timesteps: 1200
# Best mean reward: -84.00 - Last mean reward per episode: -1346.32
# Num timesteps: 1220
# Best mean reward: -84.00 - Last mean reward per episode: -1346.32
# Num timesteps: 1240
# Best mean reward: -84.00 - Last mean reward per episode: -1346.32
# Num timesteps: 1260
# Best mean reward: -84.00 - Last mean reward per episode: -1294.33
# Num timesteps: 1280
# Best mean reward: -84.00 - Last mean reward per episode: -1294.33
# Num timesteps: 1300
# Best mean reward: -84.00 - Last mean reward per episode: -1294.33
# Num timesteps: 1320
# Best mean reward: -84.00 - Last mean reward per episode: -1294.33
# Num timesteps: 1340
# Best mean reward: -84.00 - Last mean reward per episode: -1239.67
# Num timesteps: 1360
# Best mean reward: -84.00 - Last mean reward per episode: -1239.67
# Num timesteps: 1380
# Best mean reward: -84.00 - Last mean reward per episode: -1239.67
# Num timesteps: 1400
# Best mean reward: -84.00 - Last mean reward per episode: -1239.67
# Num timesteps: 1420
# Best mean reward: -84.00 - Last mean reward per episode: -1198.84
# Num timesteps: 1440
# Best mean reward: -84.00 - Last mean reward per episode: -1198.84
# Num timesteps: 1460
# Best mean reward: -84.00 - Last mean reward per episode: -1198.84
# Num timesteps: 1480
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1500
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1520
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1540
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1560
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1580
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1600
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1620
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1640
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1660
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1680
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1700
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1720
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1740
# Best mean reward: -84.00 - Last mean reward per episode: -1149.34
# Num timesteps: 1760
# Best mean reward: -84.00 - Last mean reward per episode: -1123.81
# Num timesteps: 1780
# Best mean reward: -84.00 - Last mean reward per episode: -1123.81
# Num timesteps: 1800
# Best mean reward: -84.00 - Last mean reward per episode: -1123.81
# Num timesteps: 1820
# Best mean reward: -84.00 - Last mean reward per episode: -1123.81
# Num timesteps: 1840
# Best mean reward: -84.00 - Last mean reward per episode: -1102.59
# Num timesteps: 1860
# Best mean reward: -84.00 - Last mean reward per episode: -1102.59
# Num timesteps: 1880
# Best mean reward: -84.00 - Last mean reward per episode: -1102.59
# Num timesteps: 1900
# Best mean reward: -84.00 - Last mean reward per episode: -1102.59
# Num timesteps: 1920
# Best mean reward: -84.00 - Last mean reward per episode: -1102.59
# Num timesteps: 1940
# Best mean reward: -84.00 - Last mean reward per episode: -1088.02
# Num timesteps: 1960
# Best mean reward: -84.00 - Last mean reward per episode: -1088.02
# Num timesteps: 1980
# Best mean reward: -84.00 - Last mean reward per episode: -1088.02
# Num timesteps: 2000
# Best mean reward: -84.00 - Last mean reward per episode: -1088.02
# Num timesteps: 2020
# Best mean reward: -84.00 - Last mean reward per episode: -1088.02
# Num timesteps: 2040
# Best mean reward: -84.00 - Last mean reward per episode: -1088.02
# Num timesteps: 2060
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2080
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2100
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2120
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2140
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2160
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2180
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2200
# Best mean reward: -84.00 - Last mean reward per episode: -1055.20
# Num timesteps: 2220
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2240
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2260
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2280
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2300
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2320
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2340
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2360
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2380
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2400
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2420
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2440
# Best mean reward: -84.00 - Last mean reward per episode: -1023.73
# Num timesteps: 2460
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2480
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2500
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2520
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2540
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2560
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2580
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2600
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2620
# Best mean reward: -84.00 - Last mean reward per episode: -983.17
# Num timesteps: 2640
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2660
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2680
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2700
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2720
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2740
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2760
# Best mean reward: -84.00 - Last mean reward per episode: -937.89
# Num timesteps: 2780
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2800
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2820
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2840
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2860
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2880
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2900
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2920
# Best mean reward: -84.00 - Last mean reward per episode: -899.51
# Num timesteps: 2940
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 2960
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 2980
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3000
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3020
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3040
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3060
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3080
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3100
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3120
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3140
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3160
# Best mean reward: -84.00 - Last mean reward per episode: -861.71
# Num timesteps: 3180
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3200
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3220
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3240
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3260
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3280
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3300
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3320
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3340
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3360
# Best mean reward: -84.00 - Last mean reward per episode: -824.76
# Num timesteps: 3380
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3400
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3420
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3440
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3460
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3480
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3500
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3520
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3540
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3560
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3580
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3600
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3620
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3640
# Best mean reward: -84.00 - Last mean reward per episode: -796.81
# Num timesteps: 3660
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3680
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3700
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3720
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3740
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3760
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3780
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3800
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3820
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3840
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3860
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3880
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3900
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3920
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3940
# Best mean reward: -84.00 - Last mean reward per episode: -768.40
# Num timesteps: 3960
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 3980
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4000
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4020
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4040
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4060
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4080
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4100
# Best mean reward: -84.00 - Last mean reward per episode: -754.30
# Num timesteps: 4120
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4140
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4160
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4180
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4200
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4220
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4240
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4260
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4280
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4300
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4320
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4340
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4360
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4380
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4400
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4420
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4440
# Best mean reward: -84.00 - Last mean reward per episode: -749.91
# Num timesteps: 4460
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4480
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4500
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4520
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4540
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4560
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4580
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4600
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4620
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4640
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4660
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4680
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4700
# Best mean reward: -84.00 - Last mean reward per episode: -749.25
# Num timesteps: 4720
# Best mean reward: -84.00 - Last mean reward per episode: -728.04
# Num timesteps: 4740
# Best mean reward: -84.00 - Last mean reward per episode: -728.04
# Num timesteps: 4760
# Best mean reward: -84.00 - Last mean reward per episode: -728.04
# Num timesteps: 4780
# Best mean reward: -84.00 - Last mean reward per episode: -728.04
# Num timesteps: 4800
# Best mean reward: -84.00 - Last mean reward per episode: -728.04
# Num timesteps: 4820
# Best mean reward: -84.00 - Last mean reward per episode: -728.04
# Num timesteps: 4840
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4860
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4880
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4900
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4920
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4940
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4960
# Best mean reward: -84.00 - Last mean reward per episode: -707.66
# Num timesteps: 4980
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5000
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5020
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5040
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5060
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5080
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5100
# Best mean reward: -84.00 - Last mean reward per episode: -689.86
# Num timesteps: 5120
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5140
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5160
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5180
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5200
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5220
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5240
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5260
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5280
# Best mean reward: -84.00 - Last mean reward per episode: -672.79
# Num timesteps: 5300
# Best mean reward: -84.00 - Last mean reward per episode: -653.69
# Num timesteps: 5320
# Best mean reward: -84.00 - Last mean reward per episode: -653.69
# Num timesteps: 5340
# Best mean reward: -84.00 - Last mean reward per episode: -653.69
# Num timesteps: 5360
# Best mean reward: -84.00 - Last mean reward per episode: -653.69
# Num timesteps: 5380
# Best mean reward: -84.00 - Last mean reward per episode: -653.69
# Num timesteps: 5400
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5420
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5440
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5460
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5480
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5500
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5520
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5540
# Best mean reward: -84.00 - Last mean reward per episode: -642.43
# Num timesteps: 5560
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5580
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5600
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5620
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5640
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5660
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5680
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5700
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5720
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5740
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5760
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5780
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5800
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5820
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5840
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5860
# Best mean reward: -84.00 - Last mean reward per episode: -630.17
# Num timesteps: 5880
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 5900
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 5920
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 5940
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 5960
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 5980
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6000
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6020
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6040
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6060
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6080
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6100
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6120
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6140
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6160
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6180
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6200
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6220
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6240
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6260
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6280
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6300
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6320
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6340
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6360
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6380
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6400
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6420
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6440
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6460
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6480
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6500
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6520
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6540
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6560
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6580
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6600
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6620
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6640
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6660
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6680
# Best mean reward: -84.00 - Last mean reward per episode: -612.23
# Num timesteps: 6700
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6720
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6740
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6760
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6780
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6800
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6820
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6840
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6860
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6880
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6900
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6920
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6940
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6960
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 6980
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7000
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7020
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7040
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7060
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7080
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7100
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7120
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7140
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7160
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7180
# Best mean reward: -84.00 - Last mean reward per episode: -606.00
# Num timesteps: 7200
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7220
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7240
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7260
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7280
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7300
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7320
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7340
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7360
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7380
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7400
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7420
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7440
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7460
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7480
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7500
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7520
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7540
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7560
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7580
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7600
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7620
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7640
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7660
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7680
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7700
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7720
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7740
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7760
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7780
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7800
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7820
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7840
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7860
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7880
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7900
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7920
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7940
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7960
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 7980
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8000
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8020
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8040
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8060
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8080
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8100
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8120
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8140
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8160
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8180
# Best mean reward: -84.00 - Last mean reward per episode: -599.11
# Num timesteps: 8200
# Best mean reward: -84.00 - Last mean reward per episode: -587.55
# Num timesteps: 8220
# Best mean reward: -84.00 - Last mean reward per episode: -587.55
# Num timesteps: 8240
# Best mean reward: -84.00 - Last mean reward per episode: -587.55
# Num timesteps: 8260
# Best mean reward: -84.00 - Last mean reward per episode: -587.55
# Num timesteps: 8280
# Best mean reward: -84.00 - Last mean reward per episode: -587.55
# Num timesteps: 8300
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8320
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8340
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8360
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8380
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8400
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8420
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8440
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8460
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8480
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8500
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8520
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8540
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8560
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8580
# Best mean reward: -84.00 - Last mean reward per episode: -574.84
# Num timesteps: 8600
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8620
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8640
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8660
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8680
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8700
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8720
# Best mean reward: -84.00 - Last mean reward per episode: -565.56
# Num timesteps: 8740
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8760
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8780
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8800
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8820
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8840
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8860
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8880
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8900
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8920
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8940
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8960
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 8980
# Best mean reward: -84.00 - Last mean reward per episode: -554.55
# Num timesteps: 9000
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9020
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9040
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9060
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9080
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9100
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9120
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9140
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9160
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9180
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9200
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9220
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9240
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9260
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9280
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9300
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9320
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9340
# Best mean reward: -84.00 - Last mean reward per episode: -543.27
# Num timesteps: 9360
# Best mean reward: -84.00 - Last mean reward per episode: -535.11
# Num timesteps: 9380
# Best mean reward: -84.00 - Last mean reward per episode: -535.11
# Num timesteps: 9400
# Best mean reward: -84.00 - Last mean reward per episode: -535.11
# Num timesteps: 9420
# Best mean reward: -84.00 - Last mean reward per episode: -535.11
# Num timesteps: 9440
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9460
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9480
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9500
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9520
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9540
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9560
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9580
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9600
# Best mean reward: -84.00 - Last mean reward per episode: -526.42
# Num timesteps: 9620
# Best mean reward: -84.00 - Last mean reward per episode: -515.62
# Num timesteps: 9640
# Best mean reward: -84.00 - Last mean reward per episode: -515.62
# Num timesteps: 9660
# Best mean reward: -84.00 - Last mean reward per episode: -515.62
# Num timesteps: 9680
# Best mean reward: -84.00 - Last mean reward per episode: -515.62
# Num timesteps: 9700
# Best mean reward: -84.00 - Last mean reward per episode: -515.62
# Num timesteps: 9720
# Best mean reward: -84.00 - Last mean reward per episode: -515.62
# Num timesteps: 9740
# Best mean reward: -84.00 - Last mean reward per episode: -507.58
# Num timesteps: 9760
# Best mean reward: -84.00 - Last mean reward per episode: -507.58
# Num timesteps: 9780
# Best mean reward: -84.00 - Last mean reward per episode: -507.58
# Num timesteps: 9800
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9820
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9840
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9860
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9880
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9900
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9920
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9940
# Best mean reward: -84.00 - Last mean reward per episode: -500.33
# Num timesteps: 9960
# Best mean reward: -84.00 - Last mean reward per episode: -493.29
# Num timesteps: 9980
# Best mean reward: -84.00 - Last mean reward per episode: -493.29
# Num timesteps: 10000
# Best mean reward: -84.00 - Last mean reward per episode: -493.29
# Num timesteps: 10020
# Best mean reward: -84.00 - Last mean reward per episode: -493.29
# Num timesteps: 10040
# Best mean reward: -84.00 - Last mean reward per episode: -493.29
# Num timesteps: 10060
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10080
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10100
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10120
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10140
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10160
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10180
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10200
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10220
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10240
# Best mean reward: -84.00 - Last mean reward per episode: -484.54
# Num timesteps: 10260
# Best mean reward: -84.00 - Last mean reward per episode: -480.27
# Num timesteps: 10280
# Best mean reward: -84.00 - Last mean reward per episode: -480.27
# Num timesteps: 10300
# Best mean reward: -84.00 - Last mean reward per episode: -480.27
# Num timesteps: 10320
# Best mean reward: -84.00 - Last mean reward per episode: -480.27
# Num timesteps: 10340
# Best mean reward: -84.00 - Last mean reward per episode: -473.16
# Num timesteps: 10360
# Best mean reward: -84.00 - Last mean reward per episode: -473.16
# Num timesteps: 10380
# Best mean reward: -84.00 - Last mean reward per episode: -473.16
# Num timesteps: 10400
# Best mean reward: -84.00 - Last mean reward per episode: -465.59
# Num timesteps: 10420
# Best mean reward: -84.00 - Last mean reward per episode: -465.59
# Num timesteps: 10440
# Best mean reward: -84.00 - Last mean reward per episode: -465.59
# Num timesteps: 10460
# Best mean reward: -84.00 - Last mean reward per episode: -465.59
# Num timesteps: 10480
# Best mean reward: -84.00 - Last mean reward per episode: -465.59
# Num timesteps: 10500
# Best mean reward: -84.00 - Last mean reward per episode: -458.58
# Num timesteps: 10520
# Best mean reward: -84.00 - Last mean reward per episode: -458.58
# Num timesteps: 10540
# Best mean reward: -84.00 - Last mean reward per episode: -458.58
# Num timesteps: 10560
# Best mean reward: -84.00 - Last mean reward per episode: -458.58
# Num timesteps: 10580
# Best mean reward: -84.00 - Last mean reward per episode: -452.88
# Num timesteps: 10600
# Best mean reward: -84.00 - Last mean reward per episode: -452.88
# Num timesteps: 10620
# Best mean reward: -84.00 - Last mean reward per episode: -452.88
# Num timesteps: 10640
# Best mean reward: -84.00 - Last mean reward per episode: -452.88
# Num timesteps: 10660
# Best mean reward: -84.00 - Last mean reward per episode: -452.88
# Num timesteps: 10680
# Best mean reward: -84.00 - Last mean reward per episode: -452.88
# Num timesteps: 10700
# Best mean reward: -84.00 - Last mean reward per episode: -445.86
# Num timesteps: 10720
# Best mean reward: -84.00 - Last mean reward per episode: -445.86
# Num timesteps: 10740
# Best mean reward: -84.00 - Last mean reward per episode: -445.86
# Num timesteps: 10760
# Best mean reward: -84.00 - Last mean reward per episode: -445.86
# Num timesteps: 10780
# Best mean reward: -84.00 - Last mean reward per episode: -440.95
# Num timesteps: 10800
# Best mean reward: -84.00 - Last mean reward per episode: -440.95
# Num timesteps: 10820
# Best mean reward: -84.00 - Last mean reward per episode: -440.95
# Num timesteps: 10840
# Best mean reward: -84.00 - Last mean reward per episode: -440.95
# Num timesteps: 10860
# Best mean reward: -84.00 - Last mean reward per episode: -440.95
# Num timesteps: 10880
# Best mean reward: -84.00 - Last mean reward per episode: -440.95
# Num timesteps: 10900
# Best mean reward: -84.00 - Last mean reward per episode: -433.33
# Num timesteps: 10920
# Best mean reward: -84.00 - Last mean reward per episode: -433.33
# Num timesteps: 10940
# Best mean reward: -84.00 - Last mean reward per episode: -433.33
# Num timesteps: 10960
# Best mean reward: -84.00 - Last mean reward per episode: -433.33
# Num timesteps: 10980
# Best mean reward: -84.00 - Last mean reward per episode: -433.33
# Num timesteps: 11000
# Best mean reward: -84.00 - Last mean reward per episode: -433.33
# Num timesteps: 11020
# Best mean reward: -84.00 - Last mean reward per episode: -425.96
# Num timesteps: 11040
# Best mean reward: -84.00 - Last mean reward per episode: -425.96
# Num timesteps: 11060
# Best mean reward: -84.00 - Last mean reward per episode: -425.96
# Num timesteps: 11080
# Best mean reward: -84.00 - Last mean reward per episode: -425.96
# Num timesteps: 11100
# Best mean reward: -84.00 - Last mean reward per episode: -425.96
# Num timesteps: 11120
# Best mean reward: -84.00 - Last mean reward per episode: -418.69
# Num timesteps: 11140
# Best mean reward: -84.00 - Last mean reward per episode: -418.69
# Num timesteps: 11160
# Best mean reward: -84.00 - Last mean reward per episode: -418.69
# Num timesteps: 11180
# Best mean reward: -84.00 - Last mean reward per episode: -418.69
# Num timesteps: 11200
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11220
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11240
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11260
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11280
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11300
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11320
# Best mean reward: -84.00 - Last mean reward per episode: -413.12
# Num timesteps: 11340
# ...
# Num timesteps: 96780
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96800
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96820
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96840
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96860
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96880
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96900
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96920
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96940
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96960
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 96980
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97000
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97020
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97040
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97060
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97080
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97100
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97120
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97140
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97160
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97180
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97200
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97220
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97240
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97260
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97280
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97300
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97320
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97340
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97360
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97380
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97400
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97420
# Best mean reward: -53.75 - Last mean reward per episode: -161.20
# Num timesteps: 97440
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97460
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97480
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97500
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97520
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97540
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97560
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97580
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97600
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97620
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97640
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97660
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97680
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97700
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97720
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97740
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97760
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97780
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97800
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97820
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97840
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97860
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97880
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97900
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97920
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97940
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97960
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 97980
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98000
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98020
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98040
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98060
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98080
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98100
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98120
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98140
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98160
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98180
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98200
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98220
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98240
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98260
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98280
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98300
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98320
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98340
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98360
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98380
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98400
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98420
# Best mean reward: -53.75 - Last mean reward per episode: -159.51
# Num timesteps: 98440
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98460
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98480
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98500
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98520
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98540
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98560
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98580
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98600
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98620
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98640
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98660
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98680
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98700
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98720
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98740
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98760
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98780
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98800
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98820
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98840
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98860
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98880
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98900
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98920
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98940
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98960
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 98980
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 99000
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 99020
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 99040
# Best mean reward: -53.75 - Last mean reward per episode: -155.95
# Num timesteps: 99060
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99080
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99100
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99120
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99140
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99160
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99180
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99200
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99220
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99240
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99260
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99280
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99300
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99320
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99340
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99360
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99380
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99400
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99420
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99440
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99460
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99480
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99500
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99520
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99540
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99560
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99580
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99600
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99620
# Best mean reward: -53.75 - Last mean reward per episode: -152.01
# Num timesteps: 99640
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99660
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99680
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99700
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99720
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99740
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99760
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99780
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99800
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99820
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99840
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99860
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99880
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99900
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99920
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99940
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99960
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 99980
# Best mean reward: -53.75 - Last mean reward per episode: -152.09
# Num timesteps: 100000
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100020
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100040
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100060
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100080
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100100
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100120
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100140
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100160
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100180
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100200
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100220
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100240
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100260
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100280
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100300
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100320
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100340
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100360
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100380
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# Num timesteps: 100400
# Best mean reward: -53.75 - Last mean reward per episode: -153.32
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:216: UserWarning: You tried to render a VecEnv with mode='human' but the render mode defined when initializing the environment must be 'human' or 'rgb_array', not 'None'.
#   warnings.warn(

# %%
from stable_baselines3.common import results_plotter

# Helper from the library
results_plotter.plot_results(
    [log_dir], 1e5, results_plotter.X_TIMESTEPS, "Acrobat"
)

# %%
def moving_average(values, window):
    """
    Smooth values by doing a moving average
    :param values: (numpy array)
    :param window: (int)
    :return: (numpy array)
    """
    weights = np.repeat(1.0, window) / window
    return np.convolve(values, weights, "valid")


def plot_results(log_folder, title="Learning Curve"):
    """
    plot the results

    :param log_folder: (str) the save location of the results to plot
    :param title: (str) the title of the task to plot
    """
    x, y = ts2xy(load_results(log_folder), "timesteps")
    y = moving_average(y, window=50)
    # Truncate x
    x = x[len(x) - len(y) :]

    fig = plt.figure(title)
    plt.plot(x, y)
    plt.xlabel("Number of Timesteps")
    plt.ylabel("Rewards")
    plt.title(title + " Smoothed")
    plt.show()

# %%
######## PUT YOUR CODE HERE ########

# x, y = ts2xy(load_results(log_dir), "timesteps")
# y = moving_average(y, window=20)




plt.plot(y, 'b', label='1.4')
plt.plot(agent_001.list_moving_average_returns,'r',label="1.1")

plt.ylabel('Return')
plt.xlabel('Episode#')
plt.title('Agent Comparison')
plt.legend()
plt.show()



######## PUT YOUR CODE HERE ########
